# %%
import os
import csv
import math
import numpy as np
from matplotlib import pyplot
# %matplotlib inline

# %%
def ouptput_labelling(X):
    for row in X:
        if row[0] == "neutral":
            row[0] = '2'    
        elif row[0] == "positive":
            row[0] = '0' 
        else:
            row[0] = '1' 
            
    return X

# %%
#data splitting
neutral_array = []
pos_array = []
neg_array = []

#data reading
reader = csv.reader(open("Tweets.csv", "r"), delimiter=",")
x = list(reader)
result = np.array(x)
result = np.delete(result ,0 ,axis = 0)
numrows = len(result)
#print(numrows)
#print(result)
#data spliting into classes
for row in result:
    if row[0] == "neutral":
        neutral_array.append(row)    
    elif row[0] == "positive":
        pos_array.append(row)
    else:
        neg_array.append(row)
        
        
neutral_array = np.array(neutral_array)
pos_array = np.array(pos_array)
neg_array = np.array(neg_array)


#print('neg',neg_array[0][1])

#splitting of actual data
np.random.shuffle(neutral_array)
numberofrows = (len(neutral_array)) * 0.8
train_data_neutral = neutral_array[0:int(numberofrows),:]
test_data_neutral = neutral_array[int(numberofrows):,:]

np.random.shuffle(pos_array)
numberofrows = (len(pos_array)) * 0.8
train_data_pos = pos_array[0:int(numberofrows),:]
test_data_pos = pos_array[int(numberofrows):,:]

np.random.shuffle(neg_array)
numberofrows = (len(neg_array)) * 0.8
train_data_neg = neg_array[0:int(numberofrows),:]
test_data_neg = neg_array[int(numberofrows):,:]

# print('neg',len(train_data_neg))
#print('pos',len(train_data_pos))
# print('neutral',len(train_data_neutral))
train_data =np.concatenate((train_data_pos,train_data_neutral,train_data_neg))
#print('train data lenght',len(train_data))
np.random.shuffle(train_data)
test_data =np.concatenate((test_data_pos,test_data_neutral,test_data_neg))
#print('test data length',len(test_data))
np.random.shuffle(test_data)



train_data_string = np.delete(train_data ,0 ,axis = 1)
train_data_output = np.delete(train_data ,1 ,axis = 1)

test_data_string = np.delete(test_data ,0 ,axis = 1)
test_data_output = np.delete(test_data ,1 ,axis = 1)
#print(test_data_output)

# %%
#labeling to binary
train_data_output = ouptput_labelling(train_data_output)
test_data_output = ouptput_labelling(test_data_output)
#print(train_data_output)
#print(test_data_output)

# %%
#preprocessing
def preprocessing(data):
    processed_data = []
    
    for row in data:
        
        row_lowercase = np.char.lower(row)
        row_punctuations_removed = remove_punctuations(row_lowercase[0])
        #print(row_punctuations_removed)
        row_emojis_removed = remove_emojis(row_punctuations_removed) 
        row_split = row_emojis_removed.split()
        processed_row = remove_stopWords(row_split) 
        processed_data.append(processed_row)
    
    return  processed_data

# %%
stopwords = ["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere", "ao", "ap", "apart", "apparently", "appear", "appreciate", "appropriate", "approximately", "ar", "are", "aren", "arent", "aren't", "arise", "around", "as", "a's", "aside", "ask", "asking", "associated", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "begin", "beginning", "beginnings", "begins", "behind", "being", "believe", "below", "beside", "besides", "best", "better", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "can't", "cause", "causes", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "cit", "cj", "cl", "clearly", "cm", "c'mon", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "contain", "containing", "contains", "corresponding", "could", "couldn", "couldnt", "couldn't", "course", "cp", "cq", "cr", "cry", "cs", "c's", "ct", "cu", "currently", "cv", "cx", "cy", "cz", "d", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", "di", "did", "didn", "didn't", "different", "dj", "dk", "dl", "do", "does", "doesn", "doesn't", "doing", "don", "done", "don't", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "e2", "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "effect", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "empty", "en", "end", "ending", "enough", "entirely", "eo", "ep", "eq", "er", "es", "especially", "est", "et", "et-al", "etc", "eu", "ev", "even", "ever", "every", "everybody", "everyone", "everything", "everywhere", "ex", "exactly", "example", "except", "ey", "f", "f2", "fa", "far", "fc", "few", "ff", "fi", "fifteen", "fifth", "fify", "fill", "find", "fire", "first", "five", "fix", "fj", "fl", "fn", "fo", "followed", "following", "follows", "for", "former", "formerly", "forth", "forty", "found", "four", "fr", "from", "front", "fs", "ft", "fu", "full", "further", "furthermore", "fy", "g", "ga", "gave", "ge", "get", "gets", "getting", "gi", "give", "given", "gives", "giving", "gj", "gl", "go", "goes", "going", "gone", "got", "gotten", "gr", "greetings", "gs", "gy", "h", "h2", "h3", "had", "hadn", "hadn't", "happens", "hardly", "has", "hasn", "hasnt", "hasn't", "have", "haven", "haven't", "having", "he", "hed", "he'd", "he'll", "hello", "help", "hence", "her", "here", "hereafter", "hereby", "herein", "heres", "here's", "hereupon", "hers", "herself", "hes", "he's", "hh", "hi", "hid", "him", "himself", "his", "hither", "hj", "ho", "home", "hopefully", "how", "howbeit", "however", "how's", "hr", "hs", "http", "hu", "hundred", "hy", "i", "i2", "i3", "i4", "i6", "i7", "i8", "ia", "ib", "ibid", "ic", "id", "i'd", "ie", "if", "ig", "ignored", "ih", "ii", "ij", "il", "i'll", "im", "i'm", "immediate", "immediately", "importance", "important", "in", "inasmuch", "inc", "indeed", "index", "indicate", "indicated", "indicates", "information", "inner", "insofar", "instead", "interest", "into", "invention", "inward", "io", "ip", "iq", "ir", "is", "
ically", "specified", "specify", "specifying", "sq", "sr", "ss", "st", "still", "stop", "strongly", "sub", "substantially", "successfully", "such", "sufficiently", "suggest", "sup", "sure", "sy", "system", "sz", "t", "t1", "t2", "t3", "take", "taken", "taking", "tb", "tc", "td", "te", "tell", "ten", "tends", "tf", "th", "than", "thank", "thanks", "thanx", "that", "that'll", "thats", "that's", "that've", "the", "their", "theirs", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "thered", "therefore", "therein", "there'll", "thereof", "therere", "theres", "there's", "thereto", "thereupon", "there've", "these", "they", "theyd", "they'd", "they'll", "theyre", "they're", "they've", "thickv", "thin", "think", "third", "this", "thorough", "thoroughly", "those", "thou", "though", "thoughh", "thousand", "three", "throug", "through", "throughout", "thru", "thus", "ti", "til", "tip", "tj", "tl", "tm", "tn", "to", "together", "too", "took", "top", "toward", "towards", "tp", "tq", "tr", "tried", "tries", "truly", "try", "trying", "ts", "t's", "tt", "tv", "twelve", "twenty", "twice", "two", "tx", "u", "u201d", "ue", "ui", "uj", "uk", "um", "un", "under", "unfortunately", "unless", "unlike", "unlikely", "until", "unto", "uo", "up", "upon", "ups", "ur", "us", "use", "used", "useful", "usefully", "usefulness", "uses", "using", "usually", "ut", "v", "va", "value", "various", "vd", "ve", "ve", "very", "via", "viz", "vj", "vo", "vol", "vols", "volumtype", "vq", "vs", "vt", "vu", "w", "wa", "want", "wants", "was", "wasn", "wasnt", "wasn't", "way", "we", "wed", "we'd", "welcome", "well", "we'll", "well-b", "went", "were", "we're", "weren", "werent", "weren't", "we've", "what", "whatever", "what'll", "whats", "what's", "when", "whence", "whenever", "when's", "where", "whereafter", "whereas", "whereby", "wherein", "wheres", "where's", "whereupon", "wherever", "whether", "which", "while", "whim", "whither", "who", "whod", "whoever", "whole", "who'll", "whom", "whomever", "whos", "who's", "whose", "why", "why's", "wi", "widely", "will", "willing", "wish", "with", "within", "without", "wo", "won", "wonder", "wont", "won't", "words", "world", "would", "wouldn", "wouldnt", "wouldn't", "www", "x", "x1", "x2", "x3", "xf", "xi", "xj", "xk", "xl", "xn", "xo", "xs", "xt", "xv", "xx", "y", "y2", "yes", "yet", "yj", "yl", "you", "youd", "you'd", "you'll", "your", "youre", "you're", "yours", "yourself", "yourselves", "you've", "yr", "ys", "yt", "z", "zero", "zi", "zz"]
def remove_stopWords(string): 
    removedstring = [word for word in string if not word in stopwords]
    return removedstring

# %%
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
def remove_punctuations(string):
    no_punct = ""
    for char in string:
        if char not in punctuations:
            no_punct = no_punct + char
    return  no_punct

# %%
def remove_emojis(string):
    return string.encode('ascii', 'ignore').decode('ascii')

# %%
#creating vocabulary of unique words
def findvocab(string,vocab): 
    updatedvocab = [word for word in string if not word in vocab]
    return updatedvocab

def create_vocab(data):
    vocab = []
    
    for row in data:
        newvocab = findvocab(row,vocab)
        vocab = vocab+newvocab
    return vocab

# %%
# preprocessing entire data and creating vocabulary
processed_train_data_string = preprocessing(train_data_string)
processed_test_data_string = preprocessing(test_data_string)

processed_entire_data_string = processed_train_data_string +  processed_test_data_string


vocab_result = create_vocab(processed_train_data_string)
print(len(vocab_result))
# Out:
# 13978

# %%
# vocab processing
print('vocab lenght',len(vocab_result))
def reducefeatures(vocab,data):
    
    updated_vocab = []
    for v in vocab:
        f=0
        for row in data:
            f = f+row.count(v)
        #data ended
        # Change this to 4 
        #I am taking 100 because my system is too slow 
        #and takes a lot of time to output even only for 1 epoc with  f = 4
        if f>100:
            updated_vocab.append(v)
            
    return   updated_vocab

    
updated_vocab = reducefeatures(vocab_result,processed_train_data_string) 
print(len(updated_vocab))
# Out:
# vocab lenght 13978
# 126

# %%
 #bag of word (vector)
def find_freq(w,row):
    f = 0
    for word in row:
        if word == w:
            f +=1
    return f 

def bagofwords(row):
    vector_list = [] 
    for word in updated_vocab: 
        f = 0
        if word not in row:
            vector_list.append(f)
        
        else:
            f = find_freq(word,row)
            vector_list.append(f)
    #print('vector list',str(vector_list) )  
    return vector_list

feature_vector = list()
def create_vector(data):
     
    #vector_array.append(bagofwords(data))
    for row in data:
       # print(row)
        #print('appended')
        feature_vector.append(bagofwords(row))
        #f.write(str(bagofwords(row)))

        
create_vector(processed_train_data_string)

# %%
#reading batch from bagofwords

#soft-max function
z = [7,16,25]


def soft_max(x):
    exps = [np.exp(i) for i in x]
    summation = sum(exps)
    return exps / summation


soft_max(z)
# Out:
# array([1.52281002e-08, 1.23394574e-04, 9.99876590e-01])

# %%
#loss function

#def probability_func(X,W): 
B = [0,0,0]
Y = ['1','2']
X = [[0,2,1],[2,0,1]]
W =[[1,2,3],[4,5,6],[7,8,9]]


def loss_func(X,Y,W,B):
    m = len(X) 
    J = 0
    W = np.transpose(W)
    for i in range (0,m): 
        soft_max_result =  soft_max((np.dot(X[i],W))+B)
        logs = np.log(soft_max_result)
       
    
        if Y[i] == '0':
         
            S = logs[0]
            
           
        elif Y[i] == '1':
        
            S=logs[1]
            
           
        else :
            S=logs[2]
           
           
            
        J += S
       
        
    J = J/(-1*m)   
    return J
      
    #multiply by y respectivel and then summation
print(loss_func(X,Y,W,B))
# Out:
# 4.500123417417823

# %%
#thetas of 3 weights
def gradientDescent(X, Y,W,alpha,n_epoch,B):
    
    C1 = []
    C2 =[]
    C3 = []
    m = len(Y)
    n = len(X[0])
    J = list()
    length = int(len(X)/8)
    lenght = length+1
    print('lenght is',length)
    Sum = 0
    Sum = [Sum]+[Sum]+[Sum]

    final_Sum = list()


    for epoch in range(n_epoch):
        j = 0
        k = 0
        i = 0
        r = 0
        z = 0
        print('EPOC started')
        
        
        for z in range(length):
            print('length' ,z)
            
            j= 0 

            for j in range(n):
                Sum = [0,0,0] 
                #print(r)
                X1 = X[r:r+8]
                #print(X)
                for i in range(8):
                    soft_max_result = soft_max((np.dot(X1[i],np.transpose(W)))+B)
                   
                    
                    if Y[i+r] == '0':
                        Sub = [1,0,0]
                    elif Y[i+r] == '1':
                        Sub = [0,1,0]
                    else:
                        Sub = [0,0,1]
 
                    
                    soft_max_result = soft_max_result - Sub
                    
                    soft_max_result = np.dot(soft_max_result,X1[i][j])

                    Sum = Sum + soft_max_result
                    
             
                Sum = (Sum/8)
                Sum = Sum*alpha
                lst_W = [item[j] for item in W]

                
                Sum = lst_W - Sum
                C1.append(Sum[0])
                C2.append(Sum[1])
                C3.append(Sum[2])
                Sum = [0,0,0]
         #theetas update  
            final_Sum = [C1]+[C2]+[C3]
            W = final_Sum
            #print('loss',loss_func(X[r:r+2],Y[r:r+2],W,B))
            final_Sum = list()
            C1 = []
            C2 =[]
            C3 = []
            r = r+8
        print('loss after 1 epoc is ',loss_func(X,Y,W,B))      
            
    return W, J

# %%
n_epoch = 2
alpha = 0.01


X = feature_vector
Y = train_data_output
print(Y)
#print(X)
B = [0,0,0]



X0 = np.ones((len(X),1))
X = np.hstack((X0,X))
#print('number of columns',len(feature_vector[0]))

#W = np.zeros([len(X[0]),1], dtype = float) 
W = [0] * (len(X[0]))
W = [W]+[W]+[W]
#print('I am going')
thetas,J = gradientDescent(X ,Y,W,alpha,n_epoch,B)
#print('I am back')
print('Thetas are',np.array(thetas))

#print('Cost is ',J)
# Out:
# [['2']
#  ['1']
#  ['1']
#  ...
#  ['1']
#  ['2']
#  ['1']]
# lenght is 1463
# EPOC started
# length 0
# length 1
# length 2
# length 3
# length 4
# length 5
# length 6
# length 7
# length 8
# length 9
# length 10
# length 11
# length 12
# length 13
# length 14
# length 15
# length 16
# length 17
# length 18
# length 19
# length 20
# length 21
# length 22
# length 23
# length 24
# length 25
# length 26
# length 27
# length 28
# length 29
# length 30
# length 31
# length 32
# length 33
# length 34
# length 35
# length 36
# length 37
# length 38
# length 39
# length 40
# length 41
# length 42
# length 43
# length 44
# length 45
# length 46
# length 47
# length 48
# length 49
# length 50
# length 51
# length 52
# length 53
# length 54
# length 55
# length 56
# length 57
# length 58
# length 59
# length 60
# length 61
# length 62
# length 63
# length 64
# length 65
# length 66
# length 67
# length 68
# length 69
# length 70
# length 71
# length 72
# length 73
# length 74
# length 75
# length 76
# length 77
# length 78
# length 79
# length 80
# length 81
# length 82
# length 83
# length 84
# length 85
# length 86
# length 87
# length 88
# length 89
# length 90
# length 91
# length 92
# length 93
# length 94
# length 95
# length 96
# length 97
# length 98
# length 99
# length 100
# length 101
# length 102
# length 103
# length 104
# length 105
# length 106
# length 107
# length 108
# length 109
# length 110
# length 111
# length 112
# length 113
# length 114
# length 115
# length 116
# length 117
# length 118
# length 119
# length 120
# length 121
# length 122
# length 123
# length 124
# length 125
# length 126
# length 127
# length 128
# length 129
# length 130
# length 131
# length 132
# length 133
# length 134
# length 135
# length 136
# length 137
# length 138
# length 139
# length 140
# length 141
# length 142
# length 143
# length 144
# length 145
# length 146
# length 147
# length 148
# length 149
# length 150
# length 151
# length 152
# length 153
# length 154
# length 155
# length 156
# length 157
# length 158
# length 159
# length 160
# length 161
# length 162
# length 163
# length 164
# length 165
# length 166
# length 167
# length 168
# length 169
# length 170
# length 171
# length 172
# length 173
# length 174
# length 175
# length 176
# length 177
# length 178
# length 179
# length 180
# length 181
# length 182
# length 183
# length 184
# length 185
# length 186
# length 187
# length 188
# length 189
# length 190
# length 191
# length 192
# length 193
# length 194
# length 195
# length 196
X_test = feature_vector_testing
B = [0,0,0]

X0_test = np.ones((len(X_test),1))
X_test = np.hstack((X0_test,X_test)) 
predicted_Y = predict(X_test,thetas,B)

# %%
#confusion Matrix

def confusionMatrixPos(predicted_Y, Actual_Y):
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    #for positive
    for i in range(len(Actual_Y)): 
        if predicted_Y[i] == '0' and Actual_Y[i]== '0' :
           tp += 1
        if predicted_Y[i]== '0' and Actual_Y[i]== '1':
           fp += 1
        if predicted_Y[i]== '0' and Actual_Y[i] == '2':
           fp += 1
        if predicted_Y[i]== '1' and Actual_Y[i] == '0' :
           fn += 1
          # print('A')
        if predicted_Y[i]=='1' and Actual_Y[i] =='1' :
           tn += 1
           #print('B')
        if predicted_Y[i]=='1' and Actual_Y[i] =='2' :
           tn += 1
           #print('C')
        if predicted_Y[i]=='2' and Actual_Y[i] =='0' :
           fn += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='1' :
           tn += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='2' :
           tn += 1

    return(tp, tn, fp, fn)



def confusionMatrixNeg(predicted_Y, Actual_Y):
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for i in range(len(Actual_Y)): 
        if predicted_Y[i] == '0' and Actual_Y[i]== '0' :
           tn += 1
        if predicted_Y[i]=='0' and Actual_Y[i]== '1':
           fn += 1
        if predicted_Y[i]=='0' and Actual_Y[i] == '2':
           tn += 1
        if predicted_Y[i]=='1' and Actual_Y[i] =='0' :
           fp += 1
        if predicted_Y[i]=='1' and Actual_Y[i] =='1' :
           tp += 1
        if predicted_Y[i]=='1' and Actual_Y[i] =='2' :
           fp += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='0' :
           tn += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='1' :
           fn += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='2' :
           tn += 1

    return(tp, tn, fp, fn)



def confusionMatrixNeut(predicted_Y, Actual_Y):
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for i in range(len(Actual_Y)): 
        if predicted_Y[i] == '0' and Actual_Y[i]== '0' :
           tn += 1
        if predicted_Y[i]=='0' and Actual_Y[i]== '1':
           tn += 1
        if predicted_Y[i]=='0' and Actual_Y[i] == '2':
           fn += 1
        if predicted_Y[i]== '1' and Actual_Y[i] == '0' :
           tn += 1
        if predicted_Y[i]== '1' and Actual_Y[i] == '1' :
           tn += 1
        if predicted_Y[i]== '1' and Actual_Y[i] == '2' :
           fn += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='0' :
           fp += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='1' :
           fp += 1
        if predicted_Y[i]=='2' and Actual_Y[i] =='2' :
           tp += 1

    return(tp, tn, fp, fn)

# %%
tp0, tn0, fp0, fn0 = confusionMatrixPos(predicted_Y,test_data_output)
#print(tp, tn, fp, fn)
matrix = np.array([[tp0,fp0], [fn0,tn0]])
print('Positive Matrix')
print(matrix)

tp1, tn1, fp1, fn1 = confusionMatrixNeg(predicted_Y,test_data_output)
matrix = np.array([[tp1,fp1], [fn1,tn1]])
print('Negative Matrix')
print(matrix)

tp2, tn2, fp2, fn2 = confusionMatrixNeut(predicted_Y,test_data_output)
matrix = np.array([[tp2,fp2], [fn2,tn2]])
print('Neutral Matrix')
print(matrix)
# Out:
# Positive Matrix
# [[  17    0]
#  [ 456 2456]]
# Negative Matrix
# [[1821 1041]
#  [  15   52]]
# Neutral Matrix
# [[  29   21]
#  [ 591 2288]]

# %%
#parameters
precision0 = tp0/(tp0+fp0)
accuracy0 = (tp0+tn0)/(tp0+tn0+fp0+fn0)
recall0 = tp0/(tp0+fn0)
F1_score0 = ((precision0*recall0)/(precision0+recall0))*2
print('Class Positive')
print('precision is :',precision0)
print('accuracy is :',accuracy0)
print('recall is :',recall0)
print('F1_score is :',F1_score0)

print('Class Negative')
precision1 = tp1/(tp1+fp1)
accuracy1 = (tp1+tn1)/(tp1+tn1+fp1+fn1)
recall1 = tp1/(tp1+fn1)
F1_score1 = ((precision1*recall1)/(precision1+recall1))*2
print('precision is :',precision1)
print('accuracy is :',accuracy1)
print('recall is :',recall1)
print('F1_score is :',F1_score1)


print('Class Neutral')
precision2 = tp2/(tp2+fp2)
accuracy2 = (tp2+tn2)/(tp2+tn2+fp2+fn2)
recall2 = tp2/(tp2+fn2)
F1_score2 = ((precision2*recall2)/(precision2+recall2))*2
print('precision is :',precision2)
print('accuracy is :',accuracy2)
print('recall is :',recall2)
print('F1_score is :',F1_score2)

#macro
print('Macro Measures')
macro_precision = (precision0+precision1+precision2)/3
macro_accuracy = (accuracy0+accuracy1+accuracy2)/3
macro_recall = (recall0+recall1+recall2)/3
macro_F1_score = (F1_score0+F1_score1+F1_score2)/3

print('precision is :',macro_precision)
print('accuracy is :',macro_accuracy)
print('recall is :',macro_recall)
print('F1_score is :',macro_F1_score)


#micro
print('Micro Measures')
micro_precision  = (tp0+tp1+tp2)/(tp0+fp0+tp1+fp1+tp2+fp2)
micro_accuracy = (tp0+tn0+tp1+tn1+tp2+tn2)/(tp0+tn0+fp0+fn0+tp1+tn1+fp1+fn1+tp2+tn2+fp2+fn2)
micro_recall = (tp0+tp1+tp2)/(tp0+fn0+tp1+fn1+tp2+fn2)
micro_F1_score = ((micro_precision *micro_recall)/(micro_precision+micro_recall))*2

print('precision is :',micro_precision)
print('accuracy is :',micro_accuracy)
print('recall is :',micro_recall)
print('F1_score is :',micro_F1_score)
# Out:
# Class Positive
# precision is : 1.0
# accuracy is : 0.8443154660293616
# recall is : 0.035940803382663845
# F1_score is : 0.06938775510204082
# Class Negative
# precision is : 0.6362683438155137
# accuracy is : 0.6394673950153636
# recall is : 0.9918300653594772
# F1_score is : 0.7752234993614304
# Class Neutral
# precision is : 0.58
# accuracy is : 0.7910549675657221
# recall is : 0.0467741935483871
# F1_score is : 0.08656716417910448
# Macro Measures
# precision is : 0.7387561146051712
# accuracy is : 0.7582792762034826
# recall is : 0.35818168743017603
# F1_score is : 0.3103928062141919
# Micro Measures
# precision is : 0.6374189143052236
# accuracy is : 0.7582792762034825
# recall is : 0.6374189143052236
# F1_score is : 0.6374189143052236
